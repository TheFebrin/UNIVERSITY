# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
norm = pd.read_csv('norm.csv')
uni = pd.read_csv('uni.csv')
binomial = pd.read_csv('bin.csv')
bins = 60

# %%
sns.distplot(norm, bins=bins, hist_kws={'edgecolor' : 'black'})

# %%
sns.distplot(uni, bins=bins, hist_kws={'edgecolor' : 'black'}, kde=False)

# %%
sns.distplot(binomial, bins=bins, hist_kws={'edgecolor' : 'black'})

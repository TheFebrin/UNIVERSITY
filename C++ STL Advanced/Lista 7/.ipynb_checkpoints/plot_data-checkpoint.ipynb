# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X = []
with open('data.txt') as f:
    for line in f:
        sample = line.strip().replace('(', '').replace(')', '').split(',')
        X.append(list(map(float, sample)))

# %%
X = np.array(X)

# %%
X
# Out:
# array([[-0.127061,  0.579134],
#        [-0.125665,  0.594942],
#        [-0.124013,  0.610796],
#        ...,
#        [-0.122103, -0.626691],
#        [-0.124013, -0.610796],
#        [-0.125665, -0.594942]])

# %%
plt.figure(figsize=(15,10))
plt.scatter(X[:, 0], X[:, 1], edgecolors='black', alpha=0.5, s=50)

# %%
plt.figure(figsize=(15,10))
plt.plot(X[:, 0], X[:, 1], c='red')

# %%
plt.figure(figsize=(15,7))
plt.plot(np.arange(-30, 30, 0.01), X[:, 0])
plt.plot(np.arange(-30, 30, 0.01), X[:, 1])
plt.xlim([-30, 30])
# Out:
# (-30, 30)
